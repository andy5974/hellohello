# %% [markdown]
# # BACKGROUND

# %% [markdown]
# Objectives:
#     -To analyse stuff

# %% [markdown]
# # Import Libraries and Data

# %%
import pandas as pd

# %%
df  = pd.read_csv('../../data/raw/df_sim_confessions_250816_091219.csv', index_col =[0])

# %%
df
# Out:
#                post_id                                               text  \
# 0     2943545019041164  #SIMConfession173963\n"Tutorial how to disting...
# 1     2943544282374571  #SIMConfession173962\n"Roses are red\nViolet a...
# 2     2943543449041321  #SIMConfession173961\n"To all the girls out th...
# 3     2943542289041437  #SIMConfession173960\nHoping for the day when ...
# 4     2943539142375085  #SIMConfession173959\n"https://mustsharenews.c...
# ...                ...                                                ...
# 2190  1233660393362977  #SIMConfessions7863 my boss earn so much from ...
# 2191  1231896746872675  #SIMConfessions7852 "Would you get yourself se...
# 2192  1231655040230179            #SIMConfessions7834 LBO, POM or VSA ???
# 2193  1229768537085496  #SIMConfessions7819 "Hi! I am selling two book...
# 2194  1228090240586659  Any comments on what this guy said?\n- admin K...
#
#                                             shared_text                 time  \
# ...

# %%
df.shape
# Out:
# (2195, 10)

# %%
df.head(1)
# Out:
#             post_id                                               text  \
# 0  2943545019041164  #SIMConfession173963\n"Tutorial how to disting...
#
#   shared_text                 time image  likes  comments  shares  \
# 0         NaN  2019-12-09 07:38:02   NaN      8         0       0
#
#                                             post_url link
# 0  https://m.facebook.com/story.php?story_fbid=29...  NaN
